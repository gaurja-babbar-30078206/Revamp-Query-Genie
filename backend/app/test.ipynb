# %%
from utils.common_functions import get_gpt_mini

# %%
llm = get_gpt_mini()

# %%
from fastapi import FastAPI

# %%
from fastapi.responses import StreamingResponse

# %%
async def get_theme_insight():
    # item = insight_data['themes'][index]
    for chunk in llm.stream("What is your view on the book 1984?"):
        yield chunk.content

# %%
app = FastAPI()

# %%
@app.get("/")
async def main():
    return StreamingResponse(get_theme_insight())

# %%
data = await main()
